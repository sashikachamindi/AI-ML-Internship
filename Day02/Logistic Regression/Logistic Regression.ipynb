# %%
# import necerssary libraries

import numpy as np
import pandas as pd

# to visualizations
import matplotlib.pyplot as plt

# to divide dataset into train and test set
from sklearn.model_selection import train_test_split

# to build logistic regression model
from sklearn.linear_model import LogisticRegression

# %%
# load dataset
# csv file name : sample.csv
data = pd.read_csv("sample.csv")

# %%
# see first 5 values from dataset
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
# visualize data points
plt.scatter(data.age, data.job)

# %%
# see a column from dataset
x = data[['age']]
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y = data['job']
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %%
# import library to divide dataset into training and testing set
from sklearn.model_selection import train_test_split

# %%
# divide dataset
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     age
# 18   32
# 6    18
# 1    24
# 4    40
# 19   15
# 10   19
# 15   20
# 24   23
# 12   29
# 20   14
# 5    33
# 0    16
# 25   31
# 21   13
# 9    37
# 8    15
# 17   22
# 13   31
# 3    29
# 16   34
# 22   51
# 2    31
# 23   43

# %%
len(x_train)
# Out:
# 23

# %%
x_test
# Out:
#     age
# 14   23
# 7    36
# 11   21

# %%
len(x_test)
# Out:
# 3

# %%
# build model
model = LogisticRegression()

# %%
# train model
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# get predictions from model
model.predict(x_test)
# Out:
# array([0, 1, 0])

# %%
x_test
# Out:
#     age
# 14   23
# 7    36
# 11   21

# %%
y_test
# Out:
# 14    1
# 7     1
# 11    0
# Name: job, dtype: int64

# %%
# accuracy of model
model.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
age = pd.DataFrame({'age': [30]})
model.predict(age)
# Out:
# array([1])

# %%
ages= np.array ([[20],[40],[18],[20]])
model.predict(ages)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0, 1, 0, 0])

# %%
ages = pd.DataFrame({'age': [20, 40, 18, 20]})
model.predict(ages)
# Out:
# array([0, 1, 0, 0])
